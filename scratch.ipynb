# %%
import pandas as pd

pd.set_option('display.max_rows', 100)

# %%
df = pd.read_excel('df.xlsx')
ddf = pd.read_excel('ddf.xlsx')
dddf = pd.read_excel('dddf.xlsx')
ddddf = pd.read_excel('ddddf.xlsx')
dddddf = pd.read_excel('dddddf.xlsx')

# %%
df
# Out:
#                                wsp   wsp_id
# 0          __Bioshield Development  7854110
# 1                             ARIC  7732451
# 2                  Contracting KWS  7199698
# 3                  Contracting UPL  7382926
# 4                      Back Office  7237066
# 5     Bridge Project Longevitality  7505294
# 6              Contracting biohelp  7309056
# 7               Contracting CALYXT  8063266
# 8            Contracting Globachem  7316095
# 9   Contracting Valent Biosciences  7677577
# 10      Finance and Administration  6831851
# 11         Grants and Applications  7991757
# 12                       InfraServ  7851231
# 13              Investor relations  6588474
# 14                             R&D  6791227
# 15                           Sales  6831858

# %%
ddf
# Out:
#     wsp_id                         item     item_id  item_status
# 0  8063266  Calyxt contract development  2252786128  In Progress
# 1  8063266                 Test Project  2249183277    NO Status

# %%
merged = pd.merge(df, ddf, on='wsp_id', suffixes=('_wsp','_p'), how='outer')

# %%
merged
# Out:
#                                wsp   wsp_id                         item  \
# 0          __Bioshield Development  7854110                          NaN
# 1                             ARIC  7732451                          NaN
# 2                  Contracting KWS  7199698                          NaN
# 3                  Contracting UPL  7382926                          NaN
# 4                      Back Office  7237066                          NaN
# 5     Bridge Project Longevitality  7505294                          NaN
# 6              Contracting biohelp  7309056                          NaN
# 7               Contracting CALYXT  8063266  Calyxt contract development
# 8               Contracting CALYXT  8063266                 Test Project
# 9            Contracting Globachem  7316095                          NaN
# 10  Contracting Valent Biosciences  7677577                          NaN
# 11      Finance and Administration  6831851                          NaN
# ...

# %%
dddf
# Out:
#     wsp_id                                               item     item_id  \
# 0  8063266  Calyxt HR process development + isolation of t...  2252788703
# 1  8063266                                    Test Subproject  2249183332
# 2  6588474    Content and positioning -&gt; kickoff readyness  2256048067
# 3  6588474                     Engagement in Investment round  2256049941
# 4  6588474              Process definition and implementation  2256049459
# 5  6588474                           Prep for due dilligences  2256048822
#
#    item_status     PARENT_id
# 0  In Progress  2.252786e+09
# 1    NO Status  2.249183e+09
# 2  In Progress           NaN
# 3      Planned           NaN
# 4  In Progress           NaN
# 5      On Hold           NaN

# %%
merged = pd.merge(merged, dddf, left_on=['item_id', 'wsp_id'], right_on=['PARENT_id', 'wsp_id'], how='outer', suffixes=('_p','_s'))

# %%
merged
# Out:
#                                wsp   wsp_id                       item_p  \
# 0          __Bioshield Development  7854110                          NaN
# 1                             ARIC  7732451                          NaN
# 2                  Contracting KWS  7199698                          NaN
# 3                  Contracting UPL  7382926                          NaN
# 4                      Back Office  7237066                          NaN
# 5     Bridge Project Longevitality  7505294                          NaN
# 6              Contracting biohelp  7309056                          NaN
# 7               Contracting CALYXT  8063266  Calyxt contract development
# 8               Contracting CALYXT  8063266                 Test Project
# 9            Contracting Globachem  7316095                          NaN
# 10  Contracting Valent Biosciences  7677577                          NaN
# 11      Finance and Administration  6831851                          NaN
# ...

# %%
ddddf
# Out:
#      wsp_id                                               item     item_id  \
# 0   8063266                                      Tech transfer  2253056624
# 1   8063266  POC and establishment of isolation of target c...  2253017653
# 2   8063266                             POC biomass production  2252824738
# 3   8063266                                          Test Task  2249183396
# 4   6588474                                       Businessplan  2255948138
# 5   6588474  F&amp;A reach out to investors and add to Inve...  2171191349
# 6   6588474                             Evaluation of Evologic  2171191321
# 7   6588474                                         Pitch Deck  2256056653
# 8   6588474                                          Data Room  2171191316
# 9   6588474                                  Exploratory Phase  2293055318
# 10  6588474                                Investor Short List  2256815763
# ...

# %%
merged = pd.merge(merged, ddddf, left_on=['item_id_s', 'wsp_id'], right_on=['PARENT_id', 'wsp_id'], how='outer', suffixes=('_s','_t'))

# %%
merged
# Out:
#                                wsp   wsp_id                       item_p  \
# 0          __Bioshield Development  7854110                          NaN
# 1                             ARIC  7732451                          NaN
# 2                  Contracting KWS  7199698                          NaN
# 3                  Contracting UPL  7382926                          NaN
# 4                      Back Office  7237066                          NaN
# 5     Bridge Project Longevitality  7505294                          NaN
# 6              Contracting biohelp  7309056                          NaN
# 7               Contracting CALYXT  8063266  Calyxt contract development
# 8               Contracting CALYXT  8063266  Calyxt contract development
# 9               Contracting CALYXT  8063266  Calyxt contract development
# 10              Contracting CALYXT  8063266                 Test Project
# 11           Contracting Globachem  7316095                          NaN
# ...

# %%
dddddf
# Out:
#      wsp_id                                               item     item_id  \
# 0   8063266     POC run in 1 L bioreactor in submerged culture  2285906530
# 1   8063266                     POC liquid cultivation of HCSA  2285902062
# 2   8063266  Confirmation of comparable growth at Evologic ...  2253073294
# 3   8063266                     DoE on process intensification  2252831156
# 4   8063266                                          Test Todo  2249183486
# 5   8063266  POC and estalishment of isolation of stigmaste...  2253034130
# 6   8063266                       Lab-scale biomass production  2252932044
# 7   6588474                            Email reachout campaign  2296168921
# 8   6588474                                  Q&amp;A document   2296165990
# 9   6588474                Main terms we want in the termsheet  2290353928
# 10  6588474  Financial Model + Fin. Documents in the Data Room  2287378980
# ...

# %%
merged = pd.merge(merged, dddddf, left_on=['item_id', 'wsp_id'], right_on=['PARENT_id', 'wsp_id'], how='outer', suffixes=('_t','_d'))

# %%
merged
# Out:
#                                wsp   wsp_id                       item_p  \
# 0          __Bioshield Development  7854110                          NaN
# 1                             ARIC  7732451                          NaN
# 2                  Contracting KWS  7199698                          NaN
# 3                  Contracting UPL  7382926                          NaN
# 4                      Back Office  7237066                          NaN
# 5     Bridge Project Longevitality  7505294                          NaN
# 6              Contracting biohelp  7309056                          NaN
# 7               Contracting CALYXT  8063266  Calyxt contract development
# 8               Contracting CALYXT  8063266  Calyxt contract development
# 9               Contracting CALYXT  8063266  Calyxt contract development
# 10              Contracting CALYXT  8063266  Calyxt contract development
# 11              Contracting CALYXT  8063266  Calyxt contract development
# ...
